# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#creating a base url to use for city weather api calls
base_url = " http://api.openweathermap.org/data/2.5/weather"
#storing units as metric to use with the api calls
units = "imperial"

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['cherskiy',
#  'jieshi',
#  'pemangkat',
#  'iwaki',
#  'half moon bay',
#  'paamiut',
#  'kodiak',
#  'mataura',
#  'lagoa',
#  'port elizabeth',
#  'moose factory',
#  'sentyabrskiy',
#  'rikitea',
#  'klaksvik',
#  'arlit',
#  'boa vista',
#  'mount gambier',
#  'taolanaro',
#  'yellowknife',
#  'georgetown',
#  'knysna',
#  'luderitz',
#  'hermanus',
#  'jamestown',
#  'severo-kurilsk',
#  'yulara',
#  'punta arenas',
#  'bethel',
#  'fortuna',
#  'thompson',
#  'easton',
#  'dongsheng',
#  'kruisfontein',
#  'gornopravdinsk',
#  'kieta',
#  'prado',
#  'bluff',
#  'ixtapa',
#  'nikolskoye',
#  'busselton',
#  'nouakchott',
#  'sur',
#  'ushuaia',
#  'rocha',
#  'yenagoa',
#  'novikovo',
#  'galgani',
#  'saint-philippe',
#  'longyearbyen',
#  'waitara',
#  'nabire',
#  'tuktoyaktuk',
#  'viedma',
#  'mar del plata',
#  'craig',
#  'acireale',
#  'codrington',
#  'belushya guba',
#  'dicabisagan',
#  'sao jose da coroa grande',
#  'bredasdorp',
#  'cabo san lucas',
#  'hihifo',
#  'rio gallegos',
#  'tomatlan',
#  'mahebourg',
#  'belle glade',
#  'mount isa',
#  'huilong',
#  'pozarevac',
#  'zaysan',
#  'lolua',
#  'kapaa',
#  'ust-barguzin',
#  'south lake tahoe',
#  'yar-sale',
#  'cape town',
#  'albany',
#  'tsihombe',
#  'goderich',
#  'ajdabiya',
#  'mys shmidta',
#  'pisco',
#  'ntcheu',
#  'minab',
#  'vaini',
#  'jardim',
#  'laguna',
#  'vaasa',
#  'natal',
#  'umzimvubu',
#  'fairbanks',
#  'dakar',
#  'port alfred',
#  'lola',
#  'san patricio',
#  'beba',
#  'ocala',
#  'teknaf',
#  'tezu',
#  'chuy',
#  'hilo',
#  'saint george',
#  'broome',
#  'atuona',
#  'khatanga',
#  'datong',
#  'nuuk',
#  'saskylakh',
#  'tumannyy',
#  'avarua',
#  'fougamou',
#  'barrow',
#  'chaman',
#  'tenenkou',
#  'upernavik',
#  'kemin',
#  'jay',
#  'amalapuram',
#  'bengkulu',
#  'marcona',
#  'puerto ayora',
#  'grindavik',
#  'qaanaaq',
#  'verkhnevilyuysk',
#  'cururupu',
#  'amderma',
#  'mustasaari',
#  'sumbawa',
#  'tyumentsevo',
#  'ribeira grande',
#  'taoudenni',
#  'labuhan',
#  'yartsevo',
#  'saint-joseph',
#  'betsiamites',
#  'ajaccio',
#  'marshfield',
#  'saleaula',
#  'takapau',
#  'mrirt',
#  'kamenskoye',
#  'kununurra',
#  'zhengjiatun',
#  'iqaluit',
#  'broken hill',
#  'kavieng',
#  'grand river south east',
#  'berlevag',
#  'north bend',
#  'marzuq',
#  'stornoway',
#  'salto',
#  'baiyin',
#  'lugovoy',
#  'kuche',
#  'evensk',
#  'sitka',
#  'sioux lookout',
#  'voh',
#  'olafsvik',
#  'xuanhua',
#  'hobart',
#  'tuatapere',
#  'charleston',
#  'kahului',
#  'nizhneyansk',
#  'yakeshi',
#  'muros',
#  'illoqqortoormiut',
#  'belmonte',
#  'puerto baquerizo moreno',
#  'muravlenko',
#  'angoram',
#  'bambous virieux',
#  'yumen',
#  'teya',
#  'lodwar',
#  'ivdel',
#  'doctor pedro p. pena',
#  'port macquarie',
#  'butaritari',
#  'talnakh',
#  'los llanos de aridane',
#  'kande',
#  'castro',
#  'potsdam',
#  'kaitangata',
#  'east london',
#  'lompoc',
#  'port moresby',
#  'kimberley',
#  'ahumada',
#  'enshi',
#  'dunedin',
#  'dikson',
#  'victoria',
#  'karwar',
#  'lebu',
#  'ilulissat',
#  'mecca',
#  'gejiu',
#  'provideniya',
#  'torbay',
#  'connersville',
#  'troitsko-pechorsk',
#  'katherine',
#  'suntar',
#  'mehriz',
#  'bilma',
#  'atar',
#  'stei',
#  'tasiilaq',
#  'roald',
#  'carnarvon',
#  'lasa',
#  'new norfolk',
#  'novouzensk',
#  'clyde river',
#  'saldanha',
#  'lubao',
#  'malakal',
#  'stephenville crossing',
#  'jizan',
#  'vestmannaeyjar',
#  'kongolo',
#  'ust-nera',
#  'vardo',
#  'pervomaysk',
#  'hithadhoo',
#  'pangnirtung',
#  'kailua',
#  'temir',
#  'acapulco',
#  'adrar',
#  'souillac',
#  'porto novo',
#  'palabuhanratu',
#  'fredericton',
#  'katsuura',
#  'sao joao da barra',
#  'ancud',
#  'kasempa',
#  'sao filipe',
#  'molina',
#  'kingsport',
#  'okha',
#  'hofn',
#  'mahanoro',
#  'barbar',
#  'nome',
#  'tahe',
#  'nioro',
#  'barentsburg',
#  'buzmeyin',
#  'felanitx',
#  'rawson',
#  'antofagasta',
#  'saint-pierre',
#  'quatre cocos',
#  'hatillo',
#  'deputatskiy',
#  'sedelnikovo',
#  'vanimo',
#  'sandavagur',
#  'bandarbeyla',
#  'rungata',
#  'bilibino',
#  'manacapuru',
#  'manowa',
#  'kirakira',
#  'halifax',
#  'port-gentil',
#  'byron bay',
#  'sambava',
#  'gualeguay',
#  'jian',
#  'robertsport',
#  'tanabi',
#  'bulgan',
#  'ternate',
#  'huicheng',
#  'glendive',
#  'cidreira',
#  'vanavara',
#  'airai',
#  'steti',
#  'pontianak',
#  'beeville',
#  'darhan',
#  'lorengau',
#  'gondar',
#  'mahajanga',
#  'la orilla',
#  'aldan',
#  'kuala terengganu',
#  'luau',
#  'biak',
#  'emden',
#  'eenhana',
#  'hovd',
#  'juba',
#  'artyom',
#  'vao',
#  'birao',
#  'aden',
#  'yanan',
#  'cananea',
#  'eureka',
#  'louisbourg',
#  'geraldton',
#  'ponta do sol',
#  'baikunthpur',
#  'upington',
#  'ati',
#  'asau',
#  'changping',
#  'coahuayana',
#  'svetlyy yar',
#  'umm kaddadah',
#  'manokwari',
#  'sikea',
#  'kontagora',
#  'samana',
#  'gat',
#  'mayo',
#  'serenje',
#  'champerico',
#  'tiznit',
#  'haibowan',
#  'namibe',
#  'mabaruma',
#  'buala',
#  'champaign',
#  'yenotayevka',
#  'nemuro',
#  'cabedelo',
#  'bako',
#  'praia da vitoria',
#  'komsomolskiy',
#  'tabuk',
#  'bonavista',
#  'hamilton',
#  'esperance',
#  'firozpur',
#  'mardin',
#  'alofi',
#  'dzerzhinskoye',
#  'kloulklubed',
#  'patur',
#  'guerande',
#  'tubruq',
#  'litovko',
#  'isangel',
#  'la rioja',
#  'athabasca',
#  'iquique',
#  'kinkala',
#  'alenquer',
#  'dudinka',
#  'tabas',
#  'qurayyat',
#  'attawapiskat',
#  'khandyga',
#  'nara',
#  'tabiauea',
#  'yusva',
#  'longlac',
#  'nebolchi',
#  'faanui',
#  'volosovo',
#  'roma',
#  'benxi',
#  'katobu',
#  'portland',
#  'vostok',
#  'palembang',
#  'ghanzi',
#  'morant bay',
#  'ruteng',
#  'khonsa',
#  'petropavlovka',
#  'vaitupu',
#  'ponta delgada',
#  'pacific grove',
#  'srednekolymsk',
#  'pontes e lacerda',
#  'saint anthony',
#  'nanortalik',
#  'guerrero negro',
#  'monroe',
#  'majenang',
#  'havoysund',
#  'chokurdakh',
#  'krasnoselkup',
#  'arman',
#  'baruun-urt',
#  'manggar',
#  'linxia',
#  'ayios ioannis',
#  'naftah',
#  'omboue',
#  'noumea',
#  'aneho',
#  'karratha',
#  'pokaran',
#  'padang',
#  'tres lagoas',
#  'terrace bay',
#  'balabac',
#  'tatawin',
#  'kavaratti',
#  'pevek',
#  'ndele',
#  'ayan',
#  'karaul',
#  'qiongshan',
#  'adelanto',
#  'tautira',
#  'mitsamiouli',
#  'akdepe',
#  'guymon',
#  'natchez',
#  'nexo',
#  'kerrville',
#  'kuching',
#  'vila velha',
#  'chumikan',
#  'ahipara',
#  'berck',
#  'grand gaube',
#  'norman wells',
#  'lakatoro',
#  'hasaki',
#  'bagotville',
#  'paka',
#  'kysyl-syr',
#  'madang',
#  'hami',
#  'sola',
#  'shalinskoye',
#  'amberg',
#  'honiara',
#  'mahalapye',
#  'pervomayskoye',
#  'ulaangom',
#  'cap-aux-meules',
#  'tiksi',
#  'tateyama',
#  'dutse',
#  'dingle',
#  'kibala',
#  'kamenka',
#  'izumo',
#  'ormara',
#  'sorland',
#  'san juan',
#  'binghamton',
#  'carballo',
#  'flinders',
#  'bathsheba',
#  'kimbe',
#  'kondinskoye',
#  'oum hadjer',
#  'nouadhibou',
#  'bagdarin',
#  'college',
#  'cairns',
#  'oudtshoorn',
#  'xining',
#  'puerto vallarta',
#  'touros',
#  'eyl',
#  'urumqi',
#  'sao miguel do oeste',
#  'griffith',
#  'gasa',
#  'loudi',
#  'wanaka',
#  'bingerville',
#  'guane',
#  'yerbogachen',
#  'faya',
#  'windsor',
#  'kaduna',
#  'la ronge',
#  'narasannapeta',
#  'san vicente',
#  'bemidji',
#  'vytegra',
#  'arraial do cabo',
#  'koslan',
#  'jhikargachha',
#  'huarmey',
#  'along',
#  'rio grande',
#  'hurghada',
#  'lere',
#  'arona',
#  'trincomalee',
#  'quthing',
#  'frechen',
#  'saanen',
#  'havre-saint-pierre',
#  'port lincoln',
#  'dedougou',
#  'duluth',
#  'namatanai',
#  'beringovskiy',
#  'alegrete',
#  'quarai',
#  'general roca',
#  'samusu',
#  'vila franca do campo',
#  'opuwo',
#  'loiza',
#  'saint-augustin',
#  'manzhouli',
#  'iracoubo',
#  'novonikolayevskiy',
#  'leo',
#  'tual',
#  'mao',
#  'claveria',
#  'bisira',
#  'troitskoye',
#  'belaya gora',
#  'angra',
#  'asfi',
#  'yamada',
#  'sawakin',
#  'tuskegee',
#  'lingao',
#  'nhulunbuy',
#  'dandong',
#  'okhotsk',
#  'tura',
#  'ostersund',
#  'hualmay',
#  'tilichiki',
#  'pringsewu',
#  'zhanaozen',
#  'cascais',
#  'isla vista',
#  'korla',
#  'gbarnga',
#  'sorochinsk',
#  'kungurtug',
#  'bria',
#  'tambul',
#  'nguiu',
#  'gurupa',
#  'west bay',
#  'bereda',
#  'moshi',
#  'lavrentiya',
#  'yatou',
#  'qafqafa',
#  'santa cruz de la palma',
#  'catuday',
#  'chicama',
#  'greenfield',
#  'fare',
#  'sakakah',
#  'aguas vermelhas',
#  'sacramento',
#  'campbell river',
#  'mingshui',
#  'batagay-alyta',
#  'teluk nibung',
#  'abdanan',
#  'amahai',
#  'port-cartier',
#  'loa janan',
#  'shishou',
#  'sinnamary',
#  'bauchi',
#  'durban',
#  'clearwater',
#  'sinkat',
#  'acatlan',
#  'wattegama',
#  'brewster',
#  'estevan',
#  'naze',
#  'ostrovnoy',
#  'port blair',
#  'narsaq',
#  'tygda',
#  'lugo',
#  'tabarqah',
#  'kholbon',
#  'kokopo',
#  'spring hill',
#  'elko',
#  'artvin',
#  'miri',
#  'hervey bay',
#  'ust-kamchatsk',
#  'havelock',
#  'sinjar',
#  'nyurba',
#  'sirjan',
#  'sumbe',
#  'peace river',
#  'te anau',
#  'dustlik',
#  'pirmasens',
#  'qinzhou',
#  'kpandu',
#  'auki',
#  'ituni',
#  'husavik',
#  'boulder city',
#  'brazzaville',
#  'labutta',
#  'tarasovskiy',
#  'matamoros',
#  'ozgon']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
lat = []
lng = []
city_id = []
country = []
humidity = []
cloudiness = []
city_temps = []
wind_speed = []
date = []
min_temp = []
max_temp = []
city_name = []


for city in cities:
    
    try:
        query = f"{base_url}?q={city}&appid={weather_api_key}&units={units}"
        response = requests.get(query).json()
        print(f"The weather in {city} id: {response['id']} is {response['main']['temp']}F")
        city_name.append(response['name'])
        lat.append(round(response['coord']['lat'],2))
        lng.append(round(response['coord']['lon'],2))
        city_id.append(response['id'])
        country.append(response['sys']['country'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        city_temps.append(response['main']['temp'])
        wind_speed.append(response['wind']['speed'])
        min_temp.append(response['main']['temp_min'])
        max_temp.append(response['main']['temp_max'])
        date.append(response['dt'])
    except KeyError:
        print (f"The city {city} was not found")
# Out:
# The weather in cherskiy id: 2126199 is 16.32F
# The weather in jieshi id: 1805857 is 70.88F
# The weather in pemangkat id: 1631637 is 77.86F
# The weather in iwaki id: 2112539 is 41F
# The weather in half moon bay id: 5354943 is 58.24F
# The weather in paamiut id: 3421193 is 34.84F
# The weather in kodiak id: 5866583 is 44.6F
# The weather in mataura id: 6201424 is 41F
# The weather in lagoa id: 3372964 is 60.64F
# The weather in port elizabeth id: 964420 is 64.4F
# The weather in moose factory id: 6078372 is 53.6F
# The city sentyabrskiy was not found
# The weather in rikitea id: 4030556 is 77.36F
# The weather in klaksvik id: 2618795 is 41F
# The weather in arlit id: 2447513 is 94.44F
# The weather in boa vista id: 3664980 is 78.8F
# The weather in mount gambier id: 2156643 is 53.6F
# The city taolanaro was not found
# The weather in yellowknife id: 6185377 is 7.74F
# The weather in georgetown id: 1735106 is 78.98F
# The weather in knysna id: 988698 is 60.8F
# The weather in luderitz id: 3355672 is 61.27F
# The weather in hermanus id: 3366880 is 59F
# The weather in jamestown id: 5122534 is 50.29F
# The weather in severo-kurilsk id: 2121385 is 30.92F
# The weather in yulara id: 6355222 is 55.4F
# The weather in punta arenas id: 3874787 is 44.29F
# The weather in bethel id: 5282297 is 57.34F
# The weather in fortuna id: 5563839 is 53.98F
# The weather in thompson id: 6165406 is 46.4F
# The weather in easton id: 5188140 is 59.61F
# The weather in dongsheng id: 1812256 is 37.2F
# The weather in kruisfontein id: 986717 is 63F
# The weather in gornopravdinsk id: 1506268 is 34.75F
# The weather in kieta id: 2094027 is 80.85F
# The weather in prado id: 3452483 is 77.68F
# The weather in bluff id: 2206939 is 41F
# The weather in ixtapa id: 4004293 is 82.4F
# The weather in nikolskoye id: 546105 is 41.23F
# The weather in busselton id: 2075265 is 56.26F
# The weather in nouakchott id: 2377450 is 69.8F
# The weather in sur id: 286245 is 86.83F
# The weather in ushuaia id: 3833367 is 44.6F
# The weather in rocha id: 3440777 is 57.02F
# The weather in yenagoa id: 2318123 is 79.43F
# The weather in novikovo id: 487928 is 37.42F
# The city galgani was not found
# The weather in saint-philippe id: 935215 is 71.55F
# The weather in longyearbyen id: 2729907 is 21.2F
# The weather in waitara id: 2208091 is 52F
# The weather in nabire id: 1634614 is 75.2F
# The weather in tuktoyaktuk id: 6170031 is 8.6F
# The weather in viedma id: 3832899 is 66.74F
# The weather in mar del plata id: 3430863 is 61.48F
# The weather in craig id: 5576064 is 62.6F
# The weather in acireale id: 6540849 is 57.02F
# The weather in codrington id: 2171099 is 54.12F
# The city belushya guba was not found
# The weather in dicabisagan id: 1715015 is 74.37F
# The weather in sao jose da coroa grande id: 3388456 is 78.28F
# The weather in bredasdorp id: 1015776 is 53.6F
# The weather in cabo san lucas id: 3985710 is 79.18F
# The city hihifo was not found
# The weather in rio gallegos id: 3838859 is 69.8F
# The weather in tomatlan id: 3981391 is 91.31F
# The weather in mahebourg id: 934322 is 78.8F
# The weather in belle glade id: 4147241 is 81.68F
# The weather in mount isa id: 2065594 is 73.4F
# The weather in huilong id: 1806840 is 63.28F
# The weather in pozarevac id: 786827 is 48.78F
# The weather in zaysan id: 1517060 is 44.44F
# The city lolua was not found
# The weather in kapaa id: 5848280 is 76.15F
# The weather in ust-barguzin id: 2013986 is 27.28F
# The weather in south lake tahoe id: 5397664 is 36.28F
# The weather in yar-sale id: 1486321 is 33.62F
# The weather in cape town id: 3369157 is 62.1F
# The weather in albany id: 5106841 is 53.04F
# The city tsihombe was not found
# The weather in goderich id: 5962442 is 37.4F
# The weather in ajdabiya id: 89113 is 64.6F
# The city mys shmidta was not found
# The weather in pisco id: 3932145 is 68.43F
# The weather in ntcheu id: 924492 is 65.84F
# The weather in minab id: 123941 is 75.2F
# The weather in vaini id: 4032243 is 75.2F
# The weather in jardim id: 3460087 is 74.08F
# The weather in laguna id: 5364271 is 65.12F
# The weather in vaasa id: 632978 is 29.53F
# The weather in natal id: 3394023 is 83.34F
# The city umzimvubu was not found
# The weather in fairbanks id: 5861897 is 54.25F
# The weather in dakar id: 2253354 is 69.8F
# The weather in port alfred id: 964432 is 67.46F
# The weather in lola id: 2418092 is 73.15F
# The weather in san patricio id: 4726521 is 80.96F
# The weather in beba id: 3543961 is 89.6F
# The weather in ocala id: 4166673 is 83.1F
# The weather in teknaf id: 1185095 is 77.83F
# The weather in tezu id: 1254709 is 74.7F
# The weather in chuy id: 3443061 is 60.24F
# The weather in hilo id: 5855927 is 71.31F
# The weather in saint george id: 5546220 is 56.61F
# The weather in broome id: 5110365 is 48.96F
# The weather in atuona id: 4020109 is 79.77F
# The weather in khatanga id: 2022572 is 17.13F
# The weather in datong id: 2037799 is 44.4F
# The weather in nuuk id: 3421319 is 35.29F
# The weather in saskylakh id: 2017155 is 1.35F
# The city tumannyy was not found
# The weather in avarua id: 4035715 is 80.6F
# The weather in fougamou id: 2400578 is 75.56F
# The weather in barrow id: 5880054 is 17.6F
# The weather in chaman id: 1181611 is 73.36F
# The weather in tenenkou id: 2449938 is 96.71F
# The weather in upernavik id: 3418910 is 36.57F
# The weather in kemin id: 1528606 is 54.27F
# The weather in jay id: 4968234 is 41.74F
# The weather in amalapuram id: 1278935 is 77.86F
# The weather in bengkulu id: 1649150 is 75.27F
# The city marcona was not found
# The weather in puerto ayora id: 3652764 is 82.4F
# The weather in grindavik id: 3416888 is 46.4F
# The weather in qaanaaq id: 3831208 is 39.31F
# The weather in verkhnevilyuysk id: 2013639 is 13.8F
# The weather in cururupu id: 3401148 is 77.45F
# The city amderma was not found
# The weather in mustasaari id: 651299 is 29.53F
# The city sumbawa was not found
# The weather in tyumentsevo id: 1488741 is 47.39F
# The weather in ribeira grande id: 3372707 is 60.8F
# The weather in taoudenni id: 2450173 is 95.25F
# The weather in labuhan id: 8079926 is 76.91F
# The weather in yartsevo id: 468866 is 30.36F
# The weather in saint-joseph id: 6690296 is 71.64F
# The weather in betsiamites id: 6945992 is 41.05F
# The weather in ajaccio id: 3038333 is 59F
# The weather in marshfield id: 5261969 is 49.19F
# The city saleaula was not found
# The weather in takapau id: 2181988 is 55F
# The city mrirt was not found
# The city kamenskoye was not found
# The weather in kununurra id: 2068110 is 75.2F
# The weather in zhengjiatun id: 2033135 is 51.8F
# The weather in iqaluit id: 5983720 is 28.2F
# The weather in broken hill id: 2173911 is 48.2F
# The weather in kavieng id: 2094342 is 82.09F
# The city grand river south east was not found
# The weather in berlevag id: 780687 is 30.67F
# The weather in north bend id: 5742974 is 53.29F
# The weather in marzuq id: 72181 is 73.62F
# The weather in stornoway id: 2636790 is 46.24F
# The weather in salto id: 3440714 is 68F
# The weather in baiyin id: 1817240 is 42.8F
# The weather in lugovoy id: 1521293 is 54.21F
# The city kuche was not found
# The weather in evensk id: 2125693 is 14.67F
# The weather in sitka id: 5557293 is 51.8F
# The weather in sioux lookout id: 6148373 is 37.4F
# The weather in voh id: 2137748 is 72.18F
# The weather in olafsvik id: 3414079 is 42.37F
# The weather in xuanhua id: 2033574 is 49.57F
# The weather in hobart id: 2163355 is 42.75F
# The weather in tuatapere id: 2180815 is 41F
# The weather in charleston id: 4574324 is 72.03F
# The weather in kahului id: 5847411 is 78.42F
# The city nizhneyansk was not found
# The weather in yakeshi id: 2033536 is 34.68F
# The weather in muros id: 3115824 is 56.08F
# The city illoqqortoormiut was not found
# The weather in belmonte id: 3470137 is 78.8F
# The weather in puerto baquerizo moreno id: 3652758 is 84.2F
# The weather in muravlenko id: 1540711 is 35.6F
# The weather in angoram id: 2100765 is 73.56F
# The weather in bambous virieux id: 1106677 is 77.95F
# The weather in yumen id: 1528998 is 39.47F
# The weather in teya id: 1489656 is 28.6F
# The weather in lodwar id: 189280 is 77.5F
# The weather in ivdel id: 1505260 is 36.52F
# The city doctor pedro p. pena was not found
# The weather in port macquarie id: 2152659 is 53.02F
# The weather in butaritari id: 2110227 is 83.19F
# The weather in talnakh id: 1490256 is 10.69F
# The weather in los llanos de aridane id: 2514651 is 63.82F
# The weather in kande id: 2366168 is 87.13F
# The weather in castro id: 3466704 is 62.89F
# The weather in potsdam id: 2852458 is 39.78F
# The weather in kaitangata id: 2208248 is 43F
# The weather in east london id: 1006984 is 71.01F
# The weather in lompoc id: 5367788 is 57.97F
# The weather in port moresby id: 2088122 is 75.2F
# The weather in kimberley id: 990930 is 57.2F
# The city ahumada was not found
# The weather in enshi id: 1811720 is 57.22F
# The weather in dunedin id: 2191562 is 44.01F
# The weather in dikson id: 1507390 is 31.68F
# The weather in victoria id: 1819729 is 72.79F
# The weather in karwar id: 1267635 is 81.45F
# The weather in lebu id: 3883457 is 58.05F
# The weather in ilulissat id: 3423146 is 51.8F
# The weather in mecca id: 104515 is 85.24F
# The weather in gejiu id: 1810240 is 54.68F
# The weather in provideniya id: 4031574 is 39.2F
# The weather in torbay id: 6167817 is 40.24F
# The weather in connersville id: 4256085 is 72.48F
# The weather in troitsko-pechorsk id: 481548 is 32.49F
# The weather in katherine id: 2068655 is 73.4F
# The weather in suntar id: 2015913 is 18.66F
# The weather in mehriz id: 124274 is 75.2F
# The weather in bilma id: 2446796 is 91.04F
# The weather in atar id: 2381334 is 85.46F
# The city stei was not found
# The weather in tasiilaq id: 3424607 is 39.2F
# The weather in roald id: 3141667 is 37.99F
# The weather in carnarvon id: 2074865 is 62.6F
# The weather in lasa id: 3175096 is 48.36F
# The weather in new norfolk id: 2155415 is 45.12F
# The weather in novouzensk id: 517739 is 48.15F
# The weather in clyde river id: 5924351 is 24.8F
# The weather in saldanha id: 3361934 is 60.8F
# The weather in lubao id: 1705441 is 76.1F
# The weather in malakal id: 370737 is 77.05F
# The weather in stephenville crossing id: 6156245 is 51.28F
# The weather in jizan id: 105298 is 87.8F
# The weather in vestmannaeyjar id: 3412093 is 45.43F
# The weather in kongolo id: 212360 is 72.28F
# The weather in ust-nera id: 2120048 is 20.53F
# The weather in vardo id: 777019 is 32F
# The weather in pervomaysk id: 697593 is 40.59F
# The weather in hithadhoo id: 1282256 is 82.49F
# The weather in pangnirtung id: 6096551 is 35.6F
# The weather in kailua id: 5847486 is 78.55F
# The weather in temir id: 608036 is 55.18F
# The weather in acapulco id: 3533462 is 87.8F
# The weather in adrar id: 2381972 is 88.88F
# The weather in souillac id: 933995 is 78.8F
# The weather in porto novo id: 2392087 is 86F
# The city palabuhanratu was not found
# The weather in fredericton id: 5957776 is 41.92F
# The weather in katsuura id: 2112309 is 49.64F
# The weather in sao joao da barra id: 3448903 is 80.6F
# The weather in ancud id: 3899695 is 55.02F
# The weather in kasempa id: 912628 is 67.46F
# The weather in sao filipe id: 3374210 is 72.12F
# The weather in molina id: 3879627 is 60.8F
# The weather in kingsport id: 4634662 is 76.15F
# The weather in okha id: 2122614 is 28.47F
# The weather in hofn id: 2630299 is 39.61F
# The weather in mahanoro id: 1062553 is 72.5F
# The city barbar was not found
# The weather in nome id: 5870133 is 39.2F
# The weather in tahe id: 2034615 is 43.5F
# The weather in nioro id: 2412408 is 82.98F
# The city barentsburg was not found
# The weather in buzmeyin id: 162099 is 80.6F
# The weather in felanitx id: 2517750 is 60.69F
# The weather in rawson id: 3839307 is 69.26F
# The weather in antofagasta id: 3899539 is 66.2F
# The weather in saint-pierre id: 935214 is 72.41F
# The weather in quatre cocos id: 1106643 is 77.86F
# The weather in hatillo id: 4565346 is 80.96F
# The weather in deputatskiy id: 2028164 is 24.73F
# The city sedelnikovo was not found
# The weather in vanimo id: 2084442 is 76.87F
# The city sandavagur was not found
# The weather in bandarbeyla id: 64814 is 83.05F
# The city rungata was not found
# The weather in bilibino id: 2126682 is 22.3F
# The weather in manacapuru id: 3663529 is 73.4F
# The weather in manowa id: 2405952 is 79.27F
# The weather in kirakira id: 2178753 is 80.6F
# The weather in halifax id: 6324729 is 52.39F
# The weather in port-gentil id: 2396518 is 82.67F
# The weather in byron bay id: 2172880 is 55.47F
# The weather in sambava id: 1056899 is 75.61F
# The weather in gualeguay id: 3433663 is 63.28F
# The weather in jian id: 1806445 is 63.52F
# The weather in robertsport id: 2274275 is 82.81F
# The weather in tanabi id: 3446979 is 82.4F
# The weather in bulgan id: 2032201 is 28.38F
# The weather in ternate id: 1624041 is 80.17F
# The weather in huicheng id: 1806881 is 71.6F
# The weather in glendive id: 5654391 is 56.07F
# The weather in cidreira id: 3466165 is 66.27F
# The weather in vanavara id: 2013727 is 14.36F
# The weather in airai id: 1651810 is 55.24F
# The weather in steti id: 3065163 is 36.64F
# The weather in pontianak id: 1630789 is 75.2F
# The weather in beeville id: 4673258 is 82.92F
# The weather in darhan id: 2031964 is 34.5F
# The weather in lorengau id: 2092164 is 81.27F
# The weather in gondar id: 336014 is 57.96F
# The weather in mahajanga id: 1062663 is 77F
# The weather in la orilla id: 4001056 is 85.98F
# The weather in aldan id: 2027968 is 30.99F
# The weather in kuala terengganu id: 1734705 is 78.4F
# The weather in luau id: 876177 is 65.28F
# The weather in biak id: 1637001 is 75.58F
# The weather in emden id: 2930596 is 38.44F
# The weather in eenhana id: 3357804 is 69.8F
# The weather in hovd id: 1516048 is 32.67F
# The weather in juba id: 373303 is 70.5F
# The weather in artyom id: 587207 is 53.6F
# The weather in vao id: 2137773 is 73.62F
# The weather in birao id: 240210 is 83.82F
# The weather in aden id: 415189 is 83.28F
# The city yanan was not found
# The weather in cananea id: 4015700 is 70.38F
# The weather in eureka id: 5563397 is 57.13F
# The city louisbourg was not found
# The weather in geraldton id: 2070998 is 57.2F
# The weather in ponta do sol id: 2264557 is 57.29F
# The weather in baikunthpur id: 1277769 is 74.66F
# The weather in upington id: 945945 is 71.6F
# The weather in ati id: 2436400 is 88.65F
# The weather in asau id: 686090 is 41F
# The weather in changping id: 2038154 is 47.19F
# The weather in coahuayana id: 4013679 is 87.8F
# The weather in svetlyy yar id: 485643 is 42.4F
# The weather in umm kaddadah id: 364933 is 80.76F
# The weather in manokwari id: 1636308 is 78.64F
# The city sikea was not found
# The weather in kontagora id: 2334008 is 87.98F
# The weather in samana id: 3492997 is 87.8F
# The weather in gat id: 293842 is 62.31F
# The weather in mayo id: 4362001 is 64.13F
# The weather in serenje id: 898912 is 61.61F
# The weather in champerico id: 3598787 is 83.98F
# The weather in tiznit id: 2527087 is 59.2F
# The city haibowan was not found
# The weather in namibe id: 3347019 is 75.72F
# The weather in mabaruma id: 3377301 is 81.9F
# The weather in buala id: 2109528 is 82.36F
# The weather in champaign id: 4887163 is 77.63F
# The weather in yenotayevka id: 467479 is 42.01F
# The weather in nemuro id: 2128975 is 34.59F
# The weather in cabedelo id: 3404558 is 80.6F
# The weather in bako id: 342856 is 61.56F
# The weather in praia da vitoria id: 3372760 is 61.92F
# The weather in komsomolskiy id: 1513491 is 62.6F
# The weather in tabuk id: 1684803 is 71.67F
# The weather in bonavista id: 5905393 is 43.59F
# The weather in hamilton id: 4513583 is 73.35F
# The weather in esperance id: 2071860 is 66.2F
# The weather in firozpur id: 1271883 is 80.6F
# The weather in mardin id: 304797 is 59.11F
# The weather in alofi id: 4036284 is 82.4F
# The weather in dzerzhinskoye id: 1507035 is 36.16F
# The weather in kloulklubed id: 7671223 is 77F
# The weather in patur id: 1260035 is 87.89F
# The weather in guerande id: 3014392 is 53.62F
# The city tubruq was not found
# The weather in litovko id: 2020738 is 43.47F
# The weather in isangel id: 2136825 is 71.6F
# The weather in la rioja id: 3336897 is 56.71F
# The weather in athabasca id: 5887916 is 43.54F
# The weather in iquique id: 3887127 is 69.8F
# The weather in kinkala id: 2258984 is 73.56F
# The weather in alenquer id: 3407980 is 80.6F
# The weather in dudinka id: 1507116 is 19.58F
# The weather in tabas id: 113659 is 81.25F
# The weather in qurayyat id: 108648 is 64.4F
# The city attawapiskat was not found
# The weather in khandyga id: 2022773 is 32F
# The weather in nara id: 1855612 is 44.98F
# The city tabiauea was not found
# The city yusva was not found
# The city longlac was not found
# The weather in nebolchi id: 523051 is 33.04F
# The weather in faanui id: 4034551 is 81.1F
# The weather in volosovo id: 472357 is 42.8F
# The weather in roma id: 5134295 is 46.69F
# The weather in benxi id: 2038300 is 53.6F
# The weather in katobu id: 1640972 is 73.78F
# The weather in portland id: 5746545 is 55.96F
# The weather in vostok id: 2013279 is 35.35F
# The weather in palembang id: 1633070 is 73.92F
# The weather in ghanzi id: 933759 is 65.75F
# The weather in morant bay id: 3489440 is 83.44F
# The weather in ruteng id: 1629380 is 57.65F
# The weather in khonsa id: 1266668 is 69.03F
# The weather in petropavlovka id: 2017979 is 34.07F
# The city vaitupu was not found
# The weather in ponta delgada id: 3372783 is 60.8F
# The weather in pacific grove id: 5380437 is 57.31F
# The weather in srednekolymsk id: 2121025 is 19.53F
# The weather in pontes e lacerda id: 3453060 is 74.77F
# The weather in saint anthony id: 5044290 is 48.43F
# The weather in nanortalik id: 3421765 is 34.41F
# The weather in guerrero negro id: 4021858 is 65.88F
# The weather in monroe id: 5127305 is 48.61F
# The weather in majenang id: 1636808 is 74.28F
# The weather in havoysund id: 779622 is 31.12F
# The weather in chokurdakh id: 2126123 is 21.16F
# The weather in krasnoselkup id: 1502073 is 27.97F
# The weather in arman id: 2127060 is 18.5F
# The weather in baruun-urt id: 2032614 is 31.08F
# The weather in manggar id: 1636426 is 81.73F
# The weather in linxia id: 1803331 is 39.6F
# The weather in ayios ioannis id: 146669 is 60.84F
# The city naftah was not found
# The weather in omboue id: 2396853 is 79.27F
# The weather in noumea id: 2139521 is 73.67F
# The weather in aneho id: 2367990 is 84.2F
# The weather in karratha id: 6620339 is 74.35F
# The weather in pokaran id: 1259460 is 85.5F
# The weather in padang id: 1633419 is 77.58F
# The weather in tres lagoas id: 3446098 is 76.08F
# The weather in terrace bay id: 6162951 is 38.1F
# The weather in balabac id: 1728675 is 80.13F
# The weather in tatawin id: 2464701 is 87.8F
# The weather in kavaratti id: 1267390 is 83.95F
# The weather in pevek id: 2122090 is 19.92F
# The weather in ndele id: 237379 is 78.82F
# The weather in ayan id: 2027316 is 28.67F
# The city karaul was not found
# The weather in qiongshan id: 1797535 is 73.4F
# The weather in adelanto id: 5322400 is 55.8F
# The weather in tautira id: 4033557 is 84.09F
# The weather in mitsamiouli id: 921786 is 81.12F
# The weather in akdepe id: 601551 is 66.2F
# The weather in guymon id: 5515743 is 87.8F
# The weather in natchez id: 4437982 is 79.74F
# The weather in nexo id: 2616504 is 41F
# The weather in kerrville id: 4703078 is 78.03F
# The weather in kuching id: 1735634 is 77F
# The weather in vila velha id: 3445026 is 81.34F
# The weather in chumikan id: 2025256 is 30.49F
# The weather in ahipara id: 2194098 is 61.83F
# The weather in berck id: 3033415 is 42.8F
# The weather in grand gaube id: 934479 is 77F
# The weather in norman wells id: 6089245 is 15.8F
# The weather in lakatoro id: 2136697 is 80.06F
# The weather in hasaki id: 2112802 is 39.04F
# The weather in bagotville id: 2177254 is 54.41F
# The weather in paka id: 1734313 is 77F
# The weather in kysyl-syr id: 2021017 is 13.57F
# The weather in madang id: 2091996 is 76.05F
# The weather in hami id: 1529484 is 47.59F
# The weather in sola id: 2134814 is 81.14F
# The weather in shalinskoye id: 1492466 is 31.71F
# The weather in amberg id: 2956656 is 41.34F
# The weather in honiara id: 2108502 is 80.28F
# The weather in mahalapye id: 933471 is 65.52F
# The weather in pervomayskoye id: 797213 is 52.16F
# The weather in ulaangom id: 1515029 is 31.28F
# The weather in cap-aux-meules id: 5915327 is 41.9F
# The weather in tiksi id: 2015306 is 16.3F
# The weather in tateyama id: 1850523 is 50.11F
# The weather in dutse id: 2344245 is 87.44F
# The weather in dingle id: 1714733 is 74.71F
# The weather in kibala id: 2425791 is 89.6F
# The weather in kamenka id: 553766 is 44.01F
# The weather in izumo id: 1861084 is 39.2F
# The weather in ormara id: 1168700 is 80.69F
# The weather in sorland id: 3137469 is 32F
# The weather in san juan id: 3837213 is 75.92F
# The weather in binghamton id: 5109177 is 49.14F
# The weather in carballo id: 3126369 is 53.58F
# The weather in flinders id: 6255012 is 52.16F
# The weather in bathsheba id: 3374083 is 82.4F
# The weather in kimbe id: 2093967 is 77.56F
# The weather in kondinskoye id: 1502697 is 38.5F
# The weather in oum hadjer id: 2426370 is 88.95F
# The weather in nouadhibou id: 2377457 is 66.2F
# The weather in bagdarin id: 2027244 is 26.67F
# The weather in college id: 5859699 is 54.36F
# The weather in cairns id: 2172797 is 74.08F
# The weather in oudtshoorn id: 967106 is 60.8F
# The weather in xining id: 1788852 is 38.21F
# The weather in puerto vallarta id: 3991328 is 82.4F
# The weather in touros id: 3386213 is 82.4F
# The weather in eyl id: 60019 is 83.55F
# The weather in urumqi id: 1529102 is 50F
# The city sao miguel do oeste was not found
# The weather in griffith id: 4920986 is 76.06F
# The weather in gasa id: 281133 is 62.31F
# The weather in loudi id: 1802238 is 58.5F
# The weather in wanaka id: 2184707 is 37F
# The weather in bingerville id: 2291580 is 84.2F
# The weather in guane id: 3557758 is 79.99F
# The weather in yerbogachen id: 2012956 is 14.36F
# The weather in faya id: 110690 is 58.1F
# The weather in windsor id: 6182962 is 53.02F
# The weather in kaduna id: 2335727 is 83.93F
# The weather in la ronge id: 6050066 is 51.8F
# The weather in narasannapeta id: 1261853 is 78.46F
# The weather in san vicente id: 3428068 is 60.24F
# The weather in bemidji id: 5017822 is 40.05F
# The weather in vytegra id: 469960 is 35.11F
# The weather in arraial do cabo id: 3471451 is 77F
# The weather in koslan id: 544084 is 38.8F
# The city jhikargachha was not found
# The weather in huarmey id: 3939168 is 71.73F
# The weather in along id: 1278969 is 65.75F
# The weather in rio grande id: 3451138 is 66.83F
# The weather in hurghada id: 361291 is 77F
# The weather in lere id: 2332079 is 82.69F
# The weather in arona id: 2521582 is 64.85F
# The weather in trincomalee id: 1226260 is 81.48F
# The weather in quthing id: 932183 is 57.9F
# The weather in frechen id: 2925259 is 48.15F
# The weather in saanen id: 2658904 is 50F
# The weather in havre-saint-pierre id: 5972291 is 39.2F
# The weather in port lincoln id: 2063036 is 60.21F
# The weather in dedougou id: 2361477 is 88.38F
# The weather in duluth id: 5024719 is 34.52F
# The weather in namatanai id: 2090021 is 80.96F
# The weather in beringovskiy id: 2126710 is 32.29F
# The weather in alegrete id: 3472638 is 63.64F
# The weather in quarai id: 3452179 is 62.73F
# The weather in general roca id: 3855065 is 71.6F
# The city samusu was not found
# The weather in vila franca do campo id: 3372472 is 60.8F
# The weather in opuwo id: 3354077 is 65.64F
# The weather in loiza id: 4566022 is 83.82F
# The weather in saint-augustin id: 6137462 is 41.07F
# The weather in manzhouli id: 2035836 is 33.37F
# The weather in iracoubo id: 3381428 is 77.41F
# The weather in novonikolayevskiy id: 518488 is 44.01F
# The weather in leo id: 2358382 is 86.72F
# The weather in tual id: 1623197 is 82.99F
# The weather in mao id: 2514301 is 59F
# The weather in claveria id: 1717348 is 72.93F
# The weather in bisira id: 3702269 is 63.23F
# The weather in troitskoye id: 1489209 is 43.47F
# The weather in belaya gora id: 2126785 is 17.76F
# The city angra was not found
# The weather in asfi id: 2537881 is 63.86F
# The weather in yamada id: 2110560 is 40.59F
# The weather in sawakin id: 367544 is 83.52F
# The weather in tuskegee id: 4094490 is 78.4F
# The weather in lingao id: 1803560 is 75.56F
# The weather in nhulunbuy id: 2064735 is 77F
# The weather in dandong id: 2037886 is 50.27F
# The weather in okhotsk id: 2122605 is 21.42F
# The weather in tura id: 1254046 is 77.99F
# The weather in ostersund id: 2685750 is 32F
# The weather in hualmay id: 3939761 is 70.52F
# The weather in tilichiki id: 2120591 is 30.29F
# The weather in pringsewu id: 1630639 is 72.27F
# The weather in zhanaozen id: 607610 is 61.61F
# The weather in cascais id: 2269594 is 61.07F
# The weather in isla vista id: 5359864 is 64.33F
# The weather in korla id: 1529376 is 54.63F
# The weather in gbarnga id: 2277060 is 76.06F
# The weather in sorochinsk id: 490554 is 44.24F
# The weather in kungurtug id: 1501377 is 14.22F
# The weather in bria id: 239899 is 71.19F
# The city tambul was not found
# The city nguiu was not found
# The weather in gurupa id: 3398480 is 77.52F
# The weather in west bay id: 3580477 is 84.2F
# The weather in bereda id: 3105522 is 53.01F
# The weather in moshi id: 153209 is 71.06F
# The weather in lavrentiya id: 4031637 is 30.7F
# The weather in yatou id: 1786855 is 53.06F
# The weather in qafqafa id: 247659 is 57.2F
# The weather in santa cruz de la palma id: 2511180 is 65.19F
# The weather in catuday id: 1717787 is 76.98F
# The weather in chicama id: 3698359 is 64.4F
# The weather in greenfield id: 5255068 is 61.11F
# The weather in fare id: 4034496 is 80.92F
# The weather in sakakah id: 102527 is 82.4F
# The weather in aguas vermelhas id: 3472848 is 74.34F
# The weather in sacramento id: 5389519 is 64.2F
# The weather in campbell river id: 5914132 is 53.47F
# The weather in mingshui id: 1800498 is 60.01F
# The weather in batagay-alyta id: 2027042 is 28.08F
# The weather in teluk nibung id: 1213493 is 75.2F
# The weather in abdanan id: 145233 is 75.85F
# The weather in amahai id: 1651591 is 78.01F
# The weather in port-cartier id: 6111696 is 43.63F
# The weather in loa janan id: 1637510 is 72.86F
# The weather in shishou id: 1788268 is 58.59F
# The weather in sinnamary id: 3380290 is 77.29F
# The weather in bauchi id: 2347468 is 86.81F
# The weather in durban id: 1007311 is 65.53F
# The weather in clearwater id: 4151316 is 81.93F
# The city sinkat was not found
# The weather in acatlan id: 3533445 is 73.74F
# The weather in wattegama id: 1224061 is 73.74F
# The weather in brewster id: 5110092 is 57.04F
# The weather in estevan id: 5949568 is 51.04F
# The weather in naze id: 1855540 is 62.55F
# The weather in ostrovnoy id: 556268 is 30.06F
# The weather in port blair id: 1259385 is 81.05F
# The weather in narsaq id: 3421719 is 37.4F
# The weather in tygda id: 2014743 is 49.23F
# The weather in lugo id: 3117813 is 53.01F
# The city tabarqah was not found
# The weather in kholbon id: 2022394 is 34.47F
# The weather in kokopo id: 2093685 is 78.6F
# The weather in spring hill id: 4173838 is 86.38F
# The weather in elko id: 5703673 is 41.18F
# The weather in artvin id: 751816 is 50F
# The weather in miri id: 1738050 is 77F
# The weather in hervey bay id: 2146219 is 64.24F
# The city ust-kamchatsk was not found
# The weather in havelock id: 4470244 is 69.39F
# The weather in sinjar id: 448149 is 72.21F
# The weather in nyurba id: 2018735 is 14.92F
# The weather in sirjan id: 114259 is 66.76F
# The weather in sumbe id: 3346015 is 79.54F
# The weather in peace river id: 6100069 is 35.6F
# The weather in te anau id: 2181625 is 37.63F
# The weather in dustlik id: 1514125 is 65.61F
# The weather in pirmasens id: 2853574 is 43.56F
# The weather in qinzhou id: 1797551 is 68.16F
# The weather in kpandu id: 2299233 is 79.72F
# The weather in auki id: 2109701 is 81F
# The city ituni was not found
# The weather in husavik id: 2629833 is 37.4F
# The weather in boulder city id: 5500539 is 65.05F
# The weather in brazzaville id: 2260535 is 78.53F
# The city labutta was not found
# The weather in tarasovskiy id: 484396 is 43.2F
# The weather in matamoros id: 3996426 is 95F
# The city ozgon was not found

# %%
query = f"{base_url}?q=ostrovnoy&appid={weather_api_key}&units={units}"
response = requests.get(query).json()
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 68.0531, 'lon': 39.5131},
#  'dt': 1619469590,
#  'id': 556268,
#  'main': {'feels_like': 18.3,
#           'grnd_level': 1009,
#           'humidity': 74,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 30.06,
#           'temp_max': 30.06,
#           'temp_min': 30.06},
#  'name': 'Ostrovnoy',
#  'sys': {'country': 'RU', 'sunrise': 1619397665, 'sunset': 1619459886},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 21, 'gust': 23.13, 'speed': 17.25}}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "id": city_id,
    "city": city_name,
    "country": country,
    "lat": lat,
    "lng": lng,
    "date": date,
    "temp": city_temps,
    "max temp": max_temp,
    "humidity": humidity,
    "cloudiness": cloudiness,
    "wind speed": wind_speed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#         id           city country    lat     lng        date   temp  max temp  \
# 0  2126199       Cherskiy      RU  68.75  161.30  1619470643  16.32     16.32
# 1  1805857         Jieshi      CN  22.81  115.83  1619470643  70.88     70.88
# 2  1631637      Pemangkat      ID   1.17  108.97  1619470644  77.86     77.86
# 3  2112539          Iwaki      JP  37.05  140.88  1619470644  41.00     41.00
# 4  5354943  Half Moon Bay      US  37.46 -122.43  1619470387  58.24     61.00
#
#    humidity  cloudiness  wind speed
# 0        89          45        6.93
# 1        85         100       13.24
# 2        86          18        3.04
# 3        72           0        3.65
# 4        71          40        9.22

# %%
weather_data.to_csv(output_data_file, index = False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_100 = []

for col_name in weather_data:
    for row in weather_data['humidity']:
        if row > 100:
            humidity_100.append(row)
print(humidity_100)
# Out:
# []

# %%
#  Get the indices of cities that have humidity over 100%.

if len(humidity_100) == 0:
    print("There are no cities with humidity > 100")
else:
    print(humidity_100)
# Out:
# There are no cities with humidity > 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = weather_data['lat']
y_values = weather_data['temp']
plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.title("Latitude vs. Temperature 4/26/2021")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.grid()

plt.savefig("output_data/Latitude vs. Temperature.png")

plt.show()

# %%
#This scatter plot is comparing the latitude to the temperature. Accoridng the the scatter plot, the closer you are to the
#equater (0 degrees latitude) the higher the temperature.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = weather_data['lat']
y_values = weather_data['humidity']
plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.title("Latitude vs. Humidity 4/26/2021")
plt.xlabel('Latitude')
plt.ylabel('humidity')
plt.grid()

plt.savefig("output_data/Latitude vs. Humidity.png")

plt.show()

# %%
#This scatter plot is comparing the degrees latitude to humidity. It doesn't appear that there is any kind of correlation
#between the latitude you are located at and the humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = weather_data['lat']
y_values = weather_data['cloudiness']
plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.title("Latitude vs. Cloudiness 4/26/2021")
plt.xlabel('Latitude')
plt.ylabel('cloudiness')
plt.grid()

plt.savefig("output_data/Latitude vs. Cloudiness.png")

plt.show()

# %%
#This scatter plot is comparing the degrees latitude to cloudienss. It doesn't appear that there is any kind of correlation
#between the latitude you are located at and the cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = weather_data['lat']
y_values = weather_data['wind speed']
plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.title("Latitude vs. Wind Speed 4/26/2021")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid()

plt.savefig("output_data/Latitude vs. Wind Speed.png")

plt.show()

# %%
#This scatter plot is comparing the degrees latitude to wind speed. It doesn't appear that there is any kind of correlation
#between the latitude you are located at and the wind speed.

# %% [markdown]
# ## Linear Regression

# %%
northern_hemisphere = weather_data[weather_data['lat']>=0]
northern_hemisphere.head()
# Out:
#         id           city country    lat     lng        date   temp  max temp  \
# 0  2126199       Cherskiy      RU  68.75  161.30  1619470643  16.32     16.32
# 1  1805857         Jieshi      CN  22.81  115.83  1619470643  70.88     70.88
# 2  1631637      Pemangkat      ID   1.17  108.97  1619470644  77.86     77.86
# 3  2112539          Iwaki      JP  37.05  140.88  1619470644  41.00     41.00
# 4  5354943  Half Moon Bay      US  37.46 -122.43  1619470387  58.24     61.00
#
#    humidity  cloudiness  wind speed
# 0        89          45        6.93
# 1        85         100       13.24
# 2        86          18        3.04
# 3        72           0        3.65
# 4        71          40        9.22

# %%
southern_hemisphere = weather_data[weather_data['lat']<0]
southern_hemisphere.head()
# Out:
# 169

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['lat']
y_values = northern_hemisphere['max temp']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#print(regress_values)
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")

plt.title("Northern Hemisphere Latitude vs. Max Temp 4/26/2021")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(10,15),fontsize=15,color="red")
plt.grid()

plt.savefig("output_data/Northern Hemisphere Latitude vs. Max Temp.png")

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['lat']
y_values = southern_hemisphere['max temp']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#print(regress_values)
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")

plt.title("Southern Hemisphere Latitude vs. Max Temp 4/26/2021")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(-22,40),fontsize=15,color="red")
plt.grid()

plt.savefig("output_data/Southern Hemisphere Latitude vs. Max Temp.png")

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['lat']
y_values = northern_hemisphere['humidity']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#print(regress_values)
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")

plt.title("Northern Hemisphere Latitude vs. Humidity 4/26/2021")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(43,10),fontsize=15,color="red")
plt.grid()

plt.savefig("output_data/Northern Hemisphere Latitude vs. Humidity.png")

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['lat']
y_values = southern_hemisphere['humidity']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#print(regress_values)
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")

plt.title("Souther Hemisphere Latitude vs. Humidity 4/26/2021")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(-57,52),fontsize=15,color="red")
plt.grid()

plt.savefig("output_data/Southern Hemisphere Latitude vs. Humidity.png")

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['lat']
y_values = northern_hemisphere['cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#print(regress_values)
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")

plt.title("Northern Hemisphere Latitude vs. Humidity 4/26/2021")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(40,45),fontsize=15,color="red")
plt.grid()

plt.savefig("output_data/Northern Hemisphere Latitude vs. Cloudiness.png")

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['lat']
y_values = southern_hemisphere['cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#print(regress_values)
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")

plt.title("Southern Hemisphere Latitude vs. Cloudiness 4/26/2021")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(-50,80),fontsize=15,color="red")
plt.grid()

plt.savefig("output_data/Southern Hemisphere Latitude vs. Cloudiness.png")

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['lat']
y_values = northern_hemisphere['wind speed']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#print(regress_values)
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")

plt.title("Northern Hemisphere Latitude vs. Wind Speed (mph) 4/26/2021")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
plt.grid()

plt.savefig("output_data/Northern Hemisphere Latitude vs. Wind Speed (mph).png")

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['lat']
y_values = southern_hemisphere['wind speed']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
#print(regress_values)
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,edgecolors="black",facecolors="skyblue")
plt.plot(x_values,regress_values,"r-")

plt.title("Southern Hemisphere Latitude vs. Wind Speed (mph) 4/26/2021")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.grid()

plt.savefig("output_data/Southern Hemisphere Latitude vs. Wind Speed (mph).png")

plt.show()
